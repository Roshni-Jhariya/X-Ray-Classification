# %%
import tensorflow as tf
#import tensorflow_addons as tfa
import keras
from keras.models import Model, Sequential
from keras.layers import Activation, Dense, BatchNormalization, Dropout, Conv2D, Conv2DTranspose, MaxPooling2D, UpSampling2D, Input, Reshape,Flatten
from keras.callbacks import EarlyStopping
from keras import backend as K
from keras.models import load_model
#from tensorflow.keras.models import models
from keras.datasets import mnist
from keras.optimizers import Adam, SGD
import tensorflow as tf
import numpy as np
import pandas as pd
import glob
import PIL
from PIL import Image
import matplotlib.pyplot as plt
import cv2
import os
import sys
import sklearn
from sklearn.metrics import precision_score,recall_score,f1_score,accuracy_score, confusion_matrix
#%matplotlib inline
from tensorflow.keras import layers

from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from warnings import filterwarnings

from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession


filterwarnings('ignore')
plt.rcParams["axes.grid"] = False
np.random.seed(101)
from keras.metrics import categorical_accuracy, binary_accuracy
from keras.callbacks import EarlyStopping,ModelCheckpoint,ReduceLROnPlateau,TensorBoard
from keras.models import load_model
from sklearn.metrics import precision_score,recall_score,f1_score,accuracy_score, confusion_matrix
from scipy import misc
#from tqdm import tqdm

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
PATH = "/content/gdrive/My Drive/cOV/"

# %%
IMG_W = 256
IMG_H = 256
CHANNELS = 1

INPUT_SHAPE = (IMG_W, IMG_H, CHANNELS)
NB_CLASSES = 2
EPOCHS = 15
BATCH_SIZE = 8

# %%
os.listdir(PATH)
# Out:
# ['COVID-19', 'COVID-19 Radiography Database', 'NORMAL', 'Viral Pneumonia']

# %%
import glob
import cv2
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

X_train = []
Y_train = []
# normal [1,0,0] , COVID-19 [0,1,0], Viral Pneumonia [0,0,1]

for i in (glob.glob(PATH+'/NORMAL/*')):
    img = cv2.imread(i) # Read image here
    img=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    img=cv2.resize(img,(256,256))
    X_train.append(img)
    Y_train.append(np.array([1,0,0]))

fig = plt.figure()
fig.suptitle('normal')
plt.imshow(X_train[0], cmap='gray')

# %%
for i in (glob.glob(PATH + '/COVID-19/*')):
    img=cv2.imread(i) # Read image here
    img=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    img=cv2.resize(img,(256,256))
    Y_train.append(np.array([0,1,0]))
    X_train.append(img)

fig = plt.figure()
fig.suptitle('covid')
plt.imshow(X_train[0], cmap='gray')

# %%
viral_images = []
for img_path in glob.glob(PATH + '/Viral Pneumonia/*'):
    img=cv2.imread(img_path) # Read image here
    img=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    img=cv2.resize(img,(256,256))
    
    X_train.append(img)
    Y_train.append(np.array([0,0,1]))

fig = plt.figure()
fig.suptitle('Viral Pneumonia')
plt.imshow(X_train[1], cmap='gray')

# %%
'''
X = []
Y_train = []
cls_names = ["COVID-19/", "NORMAL/", "Viral Pneumonia/"]
# 0 refers to "COVID-19"
# 1 refers to NORMAL
# 2 refers to "Viral Pneumonia"
for cls_num in range(len(cls_names)):
    file_names = os.listdir(PATH + cls_names[cls_num])
    for fname in file_names:
        X.append(cls_names[cls_num] + fname)
        Y_train.append(cls_num)
Y_train = tf.keras.utils.to_categorical(Y)
X=np.array(X)
'''
X_train = np.array(X_train).reshape((-1,256,256,1))
Y_train = np.array(Y_train).reshape((-1,3))
print(X_train.shape)
print(Y_train.shape)
# Out:
# (2905, 256, 256, 1)
# (2905, 3)

# %%
# Using 70% data for training, 15% for validating and 15% for testing
X_t, X_test, Y_t, Y_test = train_test_split(X_train, Y_train, test_size = 0.3, random_state = 42)
X_valid, X_test, Y_valid, Y_test = train_test_split(X_test, Y_test, test_size = 0.5, random_state = 42)

# %%
def iou(y_true, y_pred, smooth = 100):
    intersection = K.sum(K.abs(y_true * y_pred), axis=-1)
    sum_ = K.sum(K.square(y_true), axis = -1) + K.sum(K.square(y_pred), axis=-1)
    jac = (intersection + smooth) / (sum_ - intersection + smooth)
    return jac


def dice_coef(y_true, y_pred, smooth=1e-6):
    y_true = tf.cast (y_true, tf.float32)
    y_pred = tf.cast (y_pred, tf.float32)
    smooth = tf.cast (smooth, tf.float32)
    
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)


def recall(y_true, y_pred):
    '''Calculates the recall, a metric for multi-label classification of
    how many relevant items are selected.
    '''
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def precision(y_true, y_pred):
    '''Calculates the precision, a metric for multi-label classification of
    how many selected items are relevant.
    '''
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def accuracy(y_true, y_pred):
    '''Calculates the mean accuracy rate across all predictions for binary
    classification problems.
    '''
    return K.mean(K.equal(y_true, K.round(y_pred)))

# %%
def My_Model(epochs_num,savename):
  img_input = Input(shape= (IMG_W, IMG_H, CHANNELS))
  x=(Conv2D(8, (3, 3), padding='same', name='conv1'))(img_input)
  x=(BatchNormalization(name='bn1')(x))
  x=(Activation('relu')(x))
  x=(MaxPooling2D()(x))

  x=(Conv2D(16, (3, 3), padding='same', name='conv2'))(x)
  x=(BatchNormalization(name='bn2')(x))
  x=(Activation('relu')(x))
  x=(MaxPooling2D()(x))

  x=(Conv2D(32, (3, 3), padding='same', name='conv3'))(x)
  x=( BatchNormalization(name='bn3')(x))
  x=(Activation('relu')(x))
  #x=(MaxPooling2D()(x))

  x=(Conv2D(16, (3, 3), padding='same', name='conv4'))(x)
  x=( BatchNormalization(name='bn4')(x))
  x=(Activation('relu')(x))
  #x=(MaxPooling2D()(x))

  
  x=(Conv2D(32, (3, 3), padding='same', name='conv5'))(x)
  x=( BatchNormalization(name='bn5')(x))
  x=(Activation('relu')(x))
  x=(MaxPooling2D()(x))

  
  x=(Conv2D(64, (3, 3), padding='same', name='conv6'))(x)
  x=( BatchNormalization(name='bn6')(x))
  x=(Activation('relu')(x))
  #x=(MaxPooling2D()(x))

  x=(Conv2D(32, (3, 3), padding='same', name='conv7'))(x)
  x=( BatchNormalization(name='bn7')(x))
  x=(Activation('relu')(x))
  #x=(MaxPooling2D()(x))

  
  x=(Conv2D(64, (3, 3), padding='same', name='conv8'))(x)
  x=( BatchNormalization(name='bn8')(x))
  x=(Activation('relu')(x))
  x=(MaxPooling2D()(x))


  
  x=(Conv2D(128, (3, 3), padding='same', name='conv9'))(x)
  x=( BatchNormalization(name='bn9')(x))
  x=(Activation('relu')(x))
  #x=(MaxPooling2D()(x))

  
  x=(Conv2D(64, (3, 3), padding='same', name='conv10'))(x)
  x=( BatchNormalization(name='bn10')(x))
  x=(Activation('relu')(x))
  #x=(MaxPooling2D()(x))

  x=(Conv2D(128, (3, 3), padding='same', name='conv11'))(x)
  x=( BatchNormalization(name='bn11')(x))
  x=(Activation('relu')(x))
  x=(MaxPooling2D()(x))

  x=(Conv2D(256, (3, 3), padding='same', name='conv12'))(x)
  x=( BatchNormalization(name='bn12')(x))
  x=(Activation('relu')(x))
  #x=(MaxPooling2D()(x))

  x=(Conv2D(128, (3, 3), padding='same', name='conv13'))(x)
  x=( BatchNormalization(name='bn13')(x))
  x=(Activation('relu')(x))
  #x=(MaxPooling2D()(x))

  x=(Conv2D(256, (3, 3), padding='same', name='conv14'))(x)
  x=( BatchNormalization(name='bn14')(x))
  x=(Activation('relu')(x))
  #x=(MaxPooling2D()(x))

  x=(Conv2D(128, (3, 3), padding='same', name='conv15'))(x)
  x=( BatchNormalization(name='bn15')(x))
  x=(Activation('relu')(x))
  #x=(MaxPooling2D()(x))

  x=(Conv2D(256, (3, 3), padding='same', name='conv16'))(x)
  x=( BatchNormalization(name='bn16')(x))
  x=(Activation('relu')(x))
  #x=(MaxPooling2D()(x))
  
  x=(Conv2D(2, (3, 3), padding='same', name='conv17'))(x)
  x=( BatchNormalization(name='bn17')(x))
  x=(Activation('relu')(x))
  #x=(MaxPooling2D()(x))
  x=(Flatten())(x)
  x= Dense(3)(x)
  pred=(Activation('softmax')(x))
  #pred=Reshape((1,256,256,1))(x)
  model=Model(inputs=img_input, outputs=pred)
  model.compile(optimizer= Adam(lr=0.001, beta_1=0.9, beta_2=0.999, amsgrad=False, decay=0.0001),
                  loss= ['categorical_crossentropy'],metrics=[iou, dice_coef,precision, recall,accuracy])#metrics=[iou, dice_coef,precision, recall,accuracy]
  history = model.fit(X_t,Y_t,BATCH_SIZE,epochs = epochs_num,validation_data=(X_valid,Y_valid),verbose=1)
  model.save(savename)
  return model,history

# %%
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 256, 256, 1)       0
# _________________________________________________________________
# conv1 (Conv2D)               (None, 256, 256, 8)       80
# _________________________________________________________________
# bn1 (BatchNormalization)     (None, 256, 256, 8)       32
# _________________________________________________________________
# activation_1 (Activation)    (None, 256, 256, 8)       0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 128, 128, 8)       0
# _________________________________________________________________
# conv2 (Conv2D)               (None, 128, 128, 16)      1168
# _________________________________________________________________
# bn2 (BatchNormalization)     (None, 128, 128, 16)      64
# _________________________________________________________________
# activation_2 (Activation)    (None, 128, 128, 16)      0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 64, 64, 16)        0
# _________________________________________________________________
# conv3 (Conv2D)               (None, 64, 64, 32)        4640
# _________________________________________________________________
# bn3 (BatchNormalization)     (None, 64, 64, 32)        128
# _________________________________________________________________
# activation_3 (Activation)    (None, 64, 64, 32)        0
# _________________________________________________________________
# conv4 (Conv2D)               (None, 64, 64, 16)        4624
# _________________________________________________________________
# bn4 (BatchNormalization)     (None, 64, 64, 16)        64
# _________________________________________________________________
# activation_4 (Activation)    (None, 64, 64, 16)        0
# _________________________________________________________________
# conv5 (Conv2D)               (None, 64, 64, 32)        4640
# _________________________________________________________________
# bn5 (BatchNormalization)     (None, 64, 64, 32)        128
# _________________________________________________________________
# activation_5 (Activation)    (None, 64, 64, 32)        0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 32, 32, 32)        0
# _________________________________________________________________
# conv6 (Conv2D)               (None, 32, 32, 64)        18496
# _________________________________________________________________
# bn6 (BatchNormalization)     (None, 32, 32, 64)        256
# _________________________________________________________________
# activation_6 (Activation)    (None, 32, 32, 64)        0
# _________________________________________________________________
# conv7 (Conv2D)               (None, 32, 32, 32)        18464
# _________________________________________________________________
# bn7 (BatchNormalization)     (None, 32, 32, 32)        128
# _________________________________________________________________
# activation_7 (Activation)    (None, 32, 32, 32)        0
# _________________________________________________________________
# conv8 (Conv2D)               (None, 32, 32, 64)        18496
# _________________________________________________________________
# bn8 (BatchNormalization)     (None, 32, 32, 64)        256
# _________________________________________________________________
# activation_8 (Activation)    (None, 32, 32, 64)        0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# conv9 (Conv2D)               (None, 16, 16, 128)       73856
# _________________________________________________________________
# bn9 (BatchNormalization)     (None, 16, 16, 128)       512
# _________________________________________________________________
# activation_9 (Activation)    (None, 16, 16, 128)       0
# _________________________________________________________________
# conv10 (Conv2D)              (None, 16, 16, 64)        73792
# _________________________________________________________________
# bn10 (BatchNormalization)    (None, 16, 16, 64)        256
# _________________________________________________________________
# activation_10 (Activation)   (None, 16, 16, 64)        0
# _________________________________________________________________
# conv11 (Conv2D)              (None, 16, 16, 128)       73856
# _________________________________________________________________
# bn11 (BatchNormalization)    (None, 16, 16, 128)       512
# _________________________________________________________________
# activation_11 (Activation)   (None, 16, 16, 128)       0
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 8, 8, 128)         0
# _________________________________________________________________
# conv12 (Conv2D)              (None, 8, 8, 256)         295168
# _________________________________________________________________
# bn12 (BatchNormalization)    (None, 8, 8, 256)         1024
# _________________________________________________________________
# activation_12 (Activation)   (None, 8, 8, 256)         0
# _________________________________________________________________
# conv13 (Conv2D)              (None, 8, 8, 128)         295040
# _________________________________________________________________
# bn13 (BatchNormalization)    (None, 8, 8, 128)         512
# _________________________________________________________________
# activation_13 (Activation)   (None, 8, 8, 128)         0
# _________________________________________________________________
# conv14 (Conv2D)              (None, 8, 8, 256)         295168
# _________________________________________________________________
# bn14 (BatchNormalization)    (None, 8, 8, 256)         1024
# _________________________________________________________________
# activation_14 (Activation)   (None, 8, 8, 256)         0
# _________________________________________________________________
# conv15 (Conv2D)              (None, 8, 8, 128)         295040
# _________________________________________________________________
# bn15 (BatchNormalization)    (None, 8, 8, 128)         512
# _________________________________________________________________
# activation_15 (Activation)   (None, 8, 8, 128)         0
# _________________________________________________________________
# conv16 (Conv2D)              (None, 8, 8, 256)         295168
# _________________________________________________________________
# bn16 (BatchNormalization)    (None, 8, 8, 256)         1024
# _________________________________________________________________
# activation_16 (Activation)   (None, 8, 8, 256)         0
# _________________________________________________________________
# conv17 (Conv2D)              (None, 8, 8, 2)           4610
# _________________________________________________________________
# bn17 (BatchNormalization)    (None, 8, 8, 2)           8
# _________________________________________________________________
# activation_17 (Activation)   (None, 8, 8, 2)           0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 387
# _________________________________________________________________
# activation_18 (Activation)   (None, 3)                 0
# =================================================================
# Total params: 1,779,133
# Trainable params: 1,775,913
# Non-trainable params: 3,220
# _________________________________________________________________

# %%
model, history = My_Model(5, 'My_Mod5.h5')
# Out:
# Train on 2033 samples, validate on 436 samples
# Epoch 1/5
# 2033/2033 [==============================] - 215s 106ms/step - loss: 0.4346 - iou: 0.9976 - dice_coef: 0.7594 - precision: 0.8565 - recall: 0.8270 - accuracy: 0.8958 - val_loss: 0.3647 - val_iou: 0.9980 - val_dice_coef: 0.8122 - val_precision: 0.8763 - val_recall: 0.8727 - val_accuracy: 0.9167
# Epoch 2/5
# 2033/2033 [==============================] - 208s 103ms/step - loss: 0.2352 - iou: 0.9988 - dice_coef: 0.8708 - precision: 0.9272 - recall: 0.9201 - accuracy: 0.9493 - val_loss: 0.2259 - val_iou: 0.9988 - val_dice_coef: 0.8417 - val_precision: 0.9383 - val_recall: 0.9114 - val_accuracy: 0.9508
# Epoch 3/5
# 2033/2033 [==============================] - 207s 102ms/step - loss: 0.1888 - iou: 0.9990 - dice_coef: 0.8972 - precision: 0.9426 - recall: 0.9377 - accuracy: 0.9601 - val_loss: 0.1702 - val_iou: 0.9991 - val_dice_coef: 0.9074 - val_precision: 0.9558 - val_recall: 0.9455 - val_accuracy: 0.9674
# Epoch 4/5
# 2033/2033 [==============================] - 210s 103ms/step - loss: 0.1605 - iou: 0.9991 - dice_coef: 0.9093 - precision: 0.9405 - recall: 0.9333 - accuracy: 0.9582 - val_loss: 0.3874 - val_iou: 0.9981 - val_dice_coef: 0.8487 - val_precision: 0.8714 - val_recall: 0.8614 - val_accuracy: 0.9114
# Epoch 5/5
# 2033/2033 [==============================] - 207s 102ms/step - loss: 0.1120 - iou: 0.9994 - dice_coef: 0.9341 - precision: 0.9608 - recall: 0.9583 - accuracy: 0.9730 - val_loss: 0.3345 - val_iou: 0.9982 - val_dice_coef: 0.8562 - val_precision: 0.8955 - val_recall: 0.8909 - val_accuracy: 0.9288

# %%
#Loading the model
img_input = Input(shape= (IMG_W, IMG_H, CHANNELS))
x=(Conv2D(8, (3, 3), padding='same', name='conv1'))(img_input)
x=(BatchNormalization(name='bn1')(x))
x=(Activation('relu')(x))
x=(MaxPooling2D()(x))

x=(Conv2D(16, (3, 3), padding='same', name='conv2'))(x)
x=(BatchNormalization(name='bn2')(x))
x=(Activation('relu')(x))
x=(MaxPooling2D()(x))

x=(Conv2D(32, (3, 3), padding='same', name='conv3'))(x)
x=( BatchNormalization(name='bn3')(x))
x=(Activation('relu')(x))
  #x=(MaxPooling2D()(x))

x=(Conv2D(16, (3, 3), padding='same', name='conv4'))(x)
x=( BatchNormalization(name='bn4')(x))
x=(Activation('relu')(x))
  #x=(MaxPooling2D()(x))

  
x=(Conv2D(32, (3, 3), padding='same', name='conv5'))(x)
x=( BatchNormalization(name='bn5')(x))
x=(Activation('relu')(x))
x=(MaxPooling2D()(x))

  
x=(Conv2D(64, (3, 3), padding='same', name='conv6'))(x)
x=( BatchNormalization(name='bn6')(x))
x=(Activation('relu')(x))
  #x=(MaxPooling2D()(x))

x=(Conv2D(32, (3, 3), padding='same', name='conv7'))(x)
x=( BatchNormalization(name='bn7')(x))
x=(Activation('relu')(x))
  #x=(MaxPooling2D()(x))

  
x=(Conv2D(64, (3, 3), padding='same', name='conv8'))(x)
x=( BatchNormalization(name='bn8')(x))
x=(Activation('relu')(x))
x=(MaxPooling2D()(x))


  
x=(Conv2D(128, (3, 3), padding='same', name='conv9'))(x)
x=( BatchNormalization(name='bn9')(x))
x=(Activation('relu')(x))
  #x=(MaxPooling2D()(x))

  
x=(Conv2D(64, (3, 3), padding='same', name='conv10'))(x)
x=( BatchNormalization(name='bn10')(x))
x=(Activation('relu')(x))
  #x=(MaxPooling2D()(x))

x=(Conv2D(128, (3, 3), padding='same', name='conv11'))(x)
x=( BatchNormalization(name='bn11')(x))
x=(Activation('relu')(x))
x=(MaxPooling2D()(x))

x=(Conv2D(256, (3, 3), padding='same', name='conv12'))(x)
x=( BatchNormalization(name='bn12')(x))
x=(Activation('relu')(x))
  #x=(MaxPooling2D()(x))

x=(Conv2D(128, (3, 3), padding='same', name='conv13'))(x)
x=( BatchNormalization(name='bn13')(x))
x=(Activation('relu')(x))
  #x=(MaxPooling2D()(x))

x=(Conv2D(256, (3, 3), padding='same', name='conv14'))(x)
x=( BatchNormalization(name='bn14')(x))
x=(Activation('relu')(x))
  #x=(MaxPooling2D()(x))

x=(Conv2D(128, (3, 3), padding='same', name='conv15'))(x)
x=( BatchNormalization(name='bn15')(x))
x=(Activation('relu')(x))
  #x=(MaxPooling2D()(x))

x=(Conv2D(256, (3, 3), padding='same', name='conv16'))(x)
x=( BatchNormalization(name='bn16')(x))
x=(Activation('relu')(x))
  #x=(MaxPooling2D()(x))
  
x=(Conv2D(2, (3, 3), padding='same', name='conv17'))(x)
x=( BatchNormalization(name='bn17')(x))
x=(Activation('relu')(x))
  #x=(MaxPooling2D()(x))
x=(Flatten())(x)
x= Dense(3)(x)
pred=(Activation('softmax')(x))

# %%
model_0 = Model(inputs=img_input, outputs=pred)
model_0.compile(optimizer= Adam(lr=0.0001, beta_1=0.9, beta_2=0.999, amsgrad=False, decay=0.0005), loss= ['categorical_crossentropy'], metrics=[iou, dice_coef,precision, recall,accuracy])

# %%
model_0.load_weights('My_Mod5.h5')

# %%
print('\n~~~~~~~~~~~~~~~Stats after 5 epoch~~~~~~~~~~~~~~~~~~~')
print('\n-------------On Train Set--------------------------\n')
res = model_0.evaluate(X_t, Y_t, batch_size= 10)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')
print('\n-------------On Test  Set--------------------------\n')
res = model_0.evaluate(X_test, Y_test, batch_size= 10)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')
print('\n-------------On validation Set---------------------\n')
res = model_0.evaluate(X_valid , Y_valid , batch_size= 10)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')
# Out:
# ~~~~~~~~~~~~~~~Stats after 5 epoch~~~~~~~~~~~~~~~~~~~
#
# -------------On Train Set--------------------------
#
# 2033/2033 [==============================] - 64s 32ms/step
# ________________________
# IOU:       |   99.87  |
# Dice Coef: |   88.62  |
# Precision: |   91.66  |
# Recall:    |   91.57  |
# Accuracy:  |   94.41  |
# Loss:      |   22.25  |
# ________________________
#
# -------------On Test  Set--------------------------
#
# 436/436 [==============================] - 13s 31ms/step
# ________________________
# IOU:       |   99.81  |
# Dice Coef: |   84.88  |
# Precision: |   86.97  |
# Recall:    |   86.82  |
# Accuracy:  |   91.29  |
# Loss:      |   33.80  |
# ________________________
#
# -------------On validation Set---------------------
#
# 436/436 [==============================] - 13s 31ms/step
# ________________________
# IOU:       |   99.82  |
# Dice Coef: |   85.69  |
# Precision: |   89.60  |
# Recall:    |   89.17  |
# Accuracy:  |   92.93  |
# Loss:      |   33.45  |
# ________________________

# %%
model, history = My_Model(epochs_num= 50, savename= ('My_Mod150.h5'))
# Out:
# Train on 2033 samples, validate on 436 samples
# Epoch 1/50
# 2033/2033 [==============================] - 217s 107ms/step - loss: 0.4055 - iou: 0.9978 - dice_coef: 0.7707 - precision: 0.8589 - recall: 0.8324 - accuracy: 0.8989 - val_loss: 0.5325 - val_iou: 0.9968 - val_dice_coef: 0.6980 - val_precision: 0.7742 - val_recall: 0.7455 - val_accuracy: 0.8424
# Epoch 2/50
# 2033/2033 [==============================] - 209s 103ms/step - loss: 0.2127 - iou: 0.9988 - dice_coef: 0.8745 - precision: 0.9305 - recall: 0.9167 - accuracy: 0.9495 - val_loss: 0.3892 - val_iou: 0.9977 - val_dice_coef: 0.8187 - val_precision: 0.8377 - val_recall: 0.8273 - val_accuracy: 0.8886
# Epoch 3/50
# 2033/2033 [==============================] - 209s 103ms/step - loss: 0.1750 - iou: 0.9990 - dice_coef: 0.8997 - precision: 0.9359 - recall: 0.9299 - accuracy: 0.9554 - val_loss: 0.3050 - val_iou: 0.9985 - val_dice_coef: 0.8757 - val_precision: 0.9039 - val_recall: 0.9000 - val_accuracy: 0.9348
# Epoch 4/50
# 2033/2033 [==============================] - 214s 105ms/step - loss: 0.1430 - iou: 0.9992 - dice_coef: 0.9206 - precision: 0.9479 - recall: 0.9446 - accuracy: 0.9642 - val_loss: 0.3884 - val_iou: 0.9981 - val_dice_coef: 0.8452 - val_precision: 0.8889 - val_recall: 0.8750 - val_accuracy: 0.9220
# Epoch 5/50
# 2033/2033 [==============================] - 210s 103ms/step - loss: 0.1079 - iou: 0.9994 - dice_coef: 0.9332 - precision: 0.9578 - recall: 0.9554 - accuracy: 0.9711 - val_loss: 0.1533 - val_iou: 0.9992 - val_dice_coef: 0.9270 - val_precision: 0.9403 - val_recall: 0.9386 - val_accuracy: 0.9598
# Epoch 6/50
# 2033/2033 [==============================] - 214s 105ms/step - loss: 0.0842 - iou: 0.9995 - dice_coef: 0.9516 - precision: 0.9721 - recall: 0.9691 - accuracy: 0.9804 - val_loss: 0.2043 - val_iou: 0.9988 - val_dice_coef: 0.8956 - val_precision: 0.9136 - val_recall: 0.9114 - val_accuracy: 0.9417
# Epoch 7/50
# 2033/2033 [==============================] - 213s 105ms/step - loss: 0.0634 - iou: 0.9997 - dice_coef: 0.9639 - precision: 0.9794 - recall: 0.9765 - accuracy: 0.9853 - val_loss: 0.1557 - val_iou: 0.9991 - val_dice_coef: 0.9258 - val_precision: 0.9432 - val_recall: 0.9409 - val_accuracy: 0.9614
# Epoch 8/50
# 2033/2033 [==============================] - 214s 105ms/step - loss: 0.0495 - iou: 0.9997 - dice_coef: 0.9675 - precision: 0.9843 - recall: 0.9814 - accuracy: 0.9886 - val_loss: 0.2002 - val_iou: 0.9989 - val_dice_coef: 0.9221 - val_precision: 0.9338 - val_recall: 0.9295 - val_accuracy: 0.9545
# Epoch 9/50
# 2033/2033 [==============================] - 215s 106ms/step - loss: 0.0596 - iou: 0.9997 - dice_coef: 0.9656 - precision: 0.9804 - recall: 0.9789 - accuracy: 0.9864 - val_loss: 0.4708 - val_iou: 0.9979 - val_dice_coef: 0.8613 - val_precision: 0.8727 - val_recall: 0.8682 - val_accuracy: 0.9136
# Epoch 10/50
# 2033/2033 [==============================] - 210s 103ms/step - loss: 0.0669 - iou: 0.9996 - dice_coef: 0.9606 - precision: 0.9725 - recall: 0.9711 - accuracy: 0.9812 - val_loss: 0.1452 - val_iou: 0.9992 - val_dice_coef: 0.9209 - val_precision: 0.9477 - val_recall: 0.9455 - val_accuracy: 0.9644
# Epoch 11/50
# 2033/2033 [==============================] - 210s 103ms/step - loss: 0.0350 - iou: 0.9998 - dice_coef: 0.9768 - precision: 0.9877 - recall: 0.9858 - accuracy: 0.9912 - val_loss: 0.2368 - val_iou: 0.9991 - val_dice_coef: 0.9323 - val_precision: 0.9474 - val_recall: 0.9432 - val_accuracy: 0.9636
# Epoch 12/50
# 2033/2033 [==============================] - 216s 106ms/step - loss: 0.0114 - iou: 0.9999 - dice_coef: 0.9917 - precision: 0.9971 - recall: 0.9971 - accuracy: 0.9980 - val_loss: 0.1146 - val_iou: 0.9994 - val_dice_coef: 0.9570 - val_precision: 0.9682 - val_recall: 0.9682 - val_accuracy: 0.9788
# Epoch 13/50
# 2033/2033 [==============================] - 211s 104ms/step - loss: 0.0311 - iou: 0.9998 - dice_coef: 0.9819 - precision: 0.9877 - recall: 0.9877 - accuracy: 0.9918 - val_loss: 0.1942 - val_iou: 0.9992 - val_dice_coef: 0.9418 - val_precision: 0.9497 - val_recall: 0.9477 - val_accuracy: 0.9659
# Epoch 14/50
# 2033/2033 [==============================] - 212s 104ms/step - loss: 0.0595 - iou: 0.9997 - dice_coef: 0.9671 - precision: 0.9778 - recall: 0.9750 - accuracy: 0.9843 - val_loss: 0.2119 - val_iou: 0.9991 - val_dice_coef: 0.9334 - val_precision: 0.9455 - val_recall: 0.9455 - val_accuracy: 0.9636
# Epoch 15/50
# 2033/2033 [==============================] - 214s 105ms/step - loss: 0.0377 - iou: 0.9998 - dice_coef: 0.9786 - precision: 0.9882 - recall: 0.9882 - accuracy: 0.9922 - val_loss: 0.2075 - val_iou: 0.9989 - val_dice_coef: 0.9167 - val_precision: 0.9227 - val_recall: 0.9227 - val_accuracy: 0.9485
# Epoch 16/50
# 2033/2033 [==============================] - 210s 104ms/step - loss: 0.0080 - iou: 1.0000 - dice_coef: 0.9932 - precision: 0.9995 - recall: 0.9990 - accuracy: 0.9995 - val_loss: 0.1678 - val_iou: 0.9992 - val_dice_coef: 0.9427 - val_precision: 0.9477 - val_recall: 0.9455 - val_accuracy: 0.9644
# Epoch 17/50
# 2033/2033 [==============================] - 212s 104ms/step - loss: 0.0077 - iou: 1.0000 - dice_coef: 0.9940 - precision: 0.9985 - recall: 0.9985 - accuracy: 0.9990 - val_loss: 0.1234 - val_iou: 0.9994 - val_dice_coef: 0.9576 - val_precision: 0.9614 - val_recall: 0.9614 - val_accuracy: 0.9742
# Epoch 18/50
# 2033/2033 [==============================] - 214s 105ms/step - loss: 7.5806e-04 - iou: 1.0000 - dice_coef: 0.9993 - precision: 1.0000 - recall: 1.0000 - accuracy: 1.0000 - val_loss: 0.1192 - val_iou: 0.9994 - val_dice_coef: 0.9574 - val_precision: 0.9591 - val_recall: 0.9591 - val_accuracy: 0.9727
# Epoch 19/50
# 2033/2033 [==============================] - 214s 105ms/step - loss: 5.7258e-04 - iou: 1.0000 - dice_coef: 0.9994 - precision: 1.0000 - recall: 1.0000 - accuracy: 1.0000 - val_loss: 0.1242 - val_iou: 0.9993 - val_dice_coef: 0.9570 - val_precision: 0.9545 - val_recall: 0.9545 - val_accuracy: 0.9697
# Epoch 20/50
# 2033/2033 [==============================] - 212s 104ms/step - loss: 2.7202e-04 - iou: 1.0000 - dice_coef: 0.9997 - precision: 1.0000 - recall: 1.0000 - accuracy: 1.0000 - val_loss: 0.1239 - val_iou: 0.9993 - val_dice_coef: 0.9570 - val_precision: 0.9568 - val_recall: 0.9568 - val_accuracy: 0.9712
# Epoch 21/50
# 2033/2033 [==============================] - 215s 106ms/step - loss: 2.1539e-04 - iou: 1.0000 - dice_coef: 0.9998 - precision: 1.0000 - recall: 1.0000 - accuracy: 1.0000 - val_loss: 0.1266 - val_iou: 0.9993 - val_dice_coef: 0.9570 - val_precision: 0.9545 - val_recall: 0.9545 - val_accuracy: 0.9697
# Epoch 22/50
# 2033/2033 [==============================] - 213s 105ms/step - loss: 2.2364e-04 - iou: 1.0000 - dice_coef: 0.9998 - precision: 1.0000 - recall: 1.0000 - accuracy: 1.0000 - val_loss: 0.1335 - val_iou: 0.9993 - val_dice_coef: 0.9576 - val_precision: 0.9545 - val_recall: 0.9545 - val_accuracy: 0.9697
# Epoch 23/50
# 2033/2033 [==============================] - 210s 103ms/step - loss: 5.3474e-04 - iou: 1.0000 - dice_coef: 0.9977 - precision: 0.9961 - recall: 0.9961 - accuracy: 0.9974 - val_loss: 0.2796 - val_iou: 0.9987 - val_dice_coef: 0.9171 - val_precision: 0.9250 - val_recall: 0.9227 - val_accuracy: 0.9492
# Epoch 24/50
# 2033/2033 [==============================] - 214s 105ms/step - loss: 0.2245 - iou: 0.9989 - dice_coef: 0.8962 - precision: 0.9289 - recall: 0.9221 - accuracy: 0.9505 - val_loss: 0.1833 - val_iou: 0.9991 - val_dice_coef: 0.9267 - val_precision: 0.9477 - val_recall: 0.9432 - val_accuracy: 0.9636
# Epoch 25/50
# 2033/2033 [==============================] - 212s 104ms/step - loss: 0.0571 - iou: 0.9997 - dice_coef: 0.9678 - precision: 0.9828 - recall: 0.9824 - accuracy: 0.9884 - val_loss: 0.1708 - val_iou: 0.9990 - val_dice_coef: 0.9225 - val_precision: 0.9409 - val_recall: 0.9364 - val_accuracy: 0.9591
# Epoch 26/50
# 2033/2033 [==============================] - 213s 105ms/step - loss: 0.0373 - iou: 0.9998 - dice_coef: 0.9770 - precision: 0.9848 - recall: 0.9843 - accuracy: 0.9897 - val_loss: 0.1855 - val_iou: 0.9991 - val_dice_coef: 0.9280 - val_precision: 0.9386 - val_recall: 0.9341 - val_accuracy: 0.9576
# Epoch 27/50
# 2033/2033 [==============================] - 217s 107ms/step - loss: 0.0102 - iou: 1.0000 - dice_coef: 0.9924 - precision: 0.9971 - recall: 0.9971 - accuracy: 0.9980 - val_loss: 0.1158 - val_iou: 0.9994 - val_dice_coef: 0.9536 - val_precision: 0.9614 - val_recall: 0.9591 - val_accuracy: 0.9735
# Epoch 28/50
# 2033/2033 [==============================] - 211s 104ms/step - loss: 0.0032 - iou: 1.0000 - dice_coef: 0.9972 - precision: 0.9995 - recall: 0.9995 - accuracy: 0.9997 - val_loss: 0.1360 - val_iou: 0.9993 - val_dice_coef: 0.9509 - val_precision: 0.9523 - val_recall: 0.9523 - val_accuracy: 0.9682
# Epoch 29/50
# 2033/2033 [==============================] - 216s 106ms/step - loss: 0.0020 - iou: 1.0000 - dice_coef: 0.9983 - precision: 0.9990 - recall: 0.9990 - accuracy: 0.9993 - val_loss: 0.1377 - val_iou: 0.9993 - val_dice_coef: 0.9488 - val_precision: 0.9545 - val_recall: 0.9545 - val_accuracy: 0.9697
# Epoch 30/50
# 2033/2033 [==============================] - 212s 104ms/step - loss: 0.0014 - iou: 1.0000 - dice_coef: 0.9987 - precision: 1.0000 - recall: 1.0000 - accuracy: 1.0000 - val_loss: 0.1390 - val_iou: 0.9993 - val_dice_coef: 0.9553 - val_precision: 0.9568 - val_recall: 0.9568 - val_accuracy: 0.9712
# Epoch 31/50
# 2033/2033 [==============================] - 213s 105ms/step - loss: 5.8658e-04 - iou: 1.0000 - dice_coef: 0.9994 - precision: 1.0000 - recall: 1.0000 - accuracy: 1.0000 - val_loss: 0.1430 - val_iou: 0.9994 - val_dice_coef: 0.9578 - val_precision: 0.9614 - val_recall: 0.9614 - val_accuracy: 0.9742
# Epoch 32/50
# 2033/2033 [==============================] - 215s 106ms/step - loss: 0.0350 - iou: 0.9998 - dice_coef: 0.9834 - precision: 0.9926 - recall: 0.9917 - accuracy: 0.9948 - val_loss: 0.1380 - val_iou: 0.9993 - val_dice_coef: 0.9483 - val_precision: 0.9568 - val_recall: 0.9568 - val_accuracy: 0.9712
# Epoch 33/50
# 2033/2033 [==============================] - 212s 104ms/step - loss: 0.0253 - iou: 0.9999 - dice_coef: 0.9866 - precision: 0.9926 - recall: 0.9926 - accuracy: 0.9951 - val_loss: 0.1901 - val_iou: 0.9991 - val_dice_coef: 0.9359 - val_precision: 0.9409 - val_recall: 0.9386 - val_accuracy: 0.9598
# Epoch 34/50
# 2033/2033 [==============================] - 214s 105ms/step - loss: 0.0247 - iou: 0.9999 - dice_coef: 0.9831 - precision: 0.9926 - recall: 0.9922 - accuracy: 0.9949 - val_loss: 0.1595 - val_iou: 0.9993 - val_dice_coef: 0.9499 - val_precision: 0.9568 - val_recall: 0.9568 - val_accuracy: 0.9712
# Epoch 35/50
# 2033/2033 [==============================] - 215s 106ms/step - loss: 0.0155 - iou: 0.9999 - dice_coef: 0.9890 - precision: 0.9941 - recall: 0.9941 - accuracy: 0.9961 - val_loss: 0.2125 - val_iou: 0.9989 - val_dice_coef: 0.9306 - val_precision: 0.9364 - val_recall: 0.9364 - val_accuracy: 0.9576
# Epoch 36/50
# 2033/2033 [==============================] - 211s 104ms/step - loss: 0.0015 - iou: 1.0000 - dice_coef: 0.9988 - precision: 0.9995 - recall: 0.9995 - accuracy: 0.9997 - val_loss: 0.1432 - val_iou: 0.9993 - val_dice_coef: 0.9564 - val_precision: 0.9610 - val_recall: 0.9591 - val_accuracy: 0.9735
# Epoch 37/50
# 2033/2033 [==============================] - 210s 103ms/step - loss: 7.8145e-04 - iou: 1.0000 - dice_coef: 0.9992 - precision: 1.0000 - recall: 1.0000 - accuracy: 1.0000 - val_loss: 0.1361 - val_iou: 0.9993 - val_dice_coef: 0.9562 - val_precision: 0.9568 - val_recall: 0.9545 - val_accuracy: 0.9705
# Epoch 38/50
# 2033/2033 [==============================] - 216s 106ms/step - loss: 3.7584e-04 - iou: 1.0000 - dice_coef: 0.9996 - precision: 1.0000 - recall: 1.0000 - accuracy: 1.0000 - val_loss: 0.1405 - val_iou: 0.9993 - val_dice_coef: 0.9568 - val_precision: 0.9591 - val_recall: 0.9591 - val_accuracy: 0.9727
# Epoch 39/50
# 2033/2033 [==============================] - 215s 106ms/step - loss: 2.9752e-04 - iou: 1.0000 - dice_coef: 0.9997 - precision: 1.0000 - recall: 1.0000 - accuracy: 1.0000 - val_loss: 0.1456 - val_iou: 0.9993 - val_dice_coef: 0.9571 - val_precision: 0.9568 - val_recall: 0.9568 - val_accuracy: 0.9712
# Epoch 40/50
# 2033/2033 [==============================] - 218s 107ms/step - loss: 1.8558e-04 - iou: 1.0000 - dice_coef: 0.9998 - precision: 1.0000 - recall: 1.0000 - accuracy: 1.0000 - val_loss: 0.1494 - val_iou: 0.9993 - val_dice_coef: 0.9569 - val_precision: 0.9591 - val_recall: 0.9591 - val_accuracy: 0.9727
# Epoch 41/50
# 2033/2033 [==============================] - 217s 107ms/step - loss: 1.3490e-04 - iou: 1.0000 - dice_coef: 0.9999 - precision: 1.0000 - recall: 1.0000 - accuracy: 1.0000 - val_loss: 0.1467 - val_iou: 0.9993 - val_dice_coef: 0.9581 - val_precision: 0.9591 - val_recall: 0.9591 - val_accuracy: 0.9727
# Epoch 42/50
# 2033/2033 [==============================] - 213s 105ms/step - loss: 1.5587e-04 - iou: 1.0000 - dice_coef: 0.9998 - precision: 1.0000 - recall: 1.0000 - accuracy: 1.0000 - val_loss: 0.1494 - val_iou: 0.9993 - val_dice_coef: 0.9581 - val_precision: 0.9591 - val_recall: 0.9591 - val_accuracy: 0.9727
# Epoch 43/50
# 2033/2033 [==============================] - 218s 107ms/step - loss: 1.2092e-04 - iou: 1.0000 - dice_coef: 0.9999 - precision: 1.0000 - recall: 1.0000 - accuracy: 1.0000 - val_loss: 0.1456 - val_iou: 0.9993 - val_dice_coef: 0.9583 - val_precision: 0.9591 - val_recall: 0.9591 - val_accuracy: 0.9727
# Epoch 44/50
# 2033/2033 [==============================] - 224s 110ms/step - loss: 1.0490e-04 - iou: 1.0000 - dice_coef: 0.9999 - precision: 1.0000 - recall: 1.0000 - accuracy: 1.0000 - val_loss: 0.1505 - val_iou: 0.9993 - val_dice_coef: 0.9574 - val_precision: 0.9591 - val_recall: 0.9591 - val_accuracy: 0.9727
# Epoch 45/50
# 2033/2033 [==============================] - 217s 107ms/step - loss: 9.3991e-05 - iou: 1.0000 - dice_coef: 0.9999 - precision: 1.0000 - recall: 1.0000 - accuracy: 1.0000 - val_loss: 0.1528 - val_iou: 0.9993 - val_dice_coef: 0.9581 - val_precision: 0.9591 - val_recall: 0.9591 - val_accuracy: 0.9727
# Epoch 46/50
# 2033/2033 [==============================] - 220s 108ms/step - loss: 7.8635e-05 - iou: 1.0000 - dice_coef: 0.9999 - precision: 1.0000 - recall: 1.0000 - accuracy: 1.0000 - val_loss: 0.1520 - val_iou: 0.9993 - val_dice_coef: 0.9587 - val_precision: 0.9591 - val_recall: 0.9591 - val_accuracy: 0.9727
# Epoch 47/50
# 2033/2033 [==============================] - 220s 108ms/step - loss: 5.3315e-05 - iou: 1.0000 - dice_coef: 0.9999 - precision: 1.0000 - recall: 1.0000 - accuracy: 1.0000 - val_loss: 0.1570 - val_iou: 0.9993 - val_dice_coef: 0.9582 - val_precision: 0.9591 - val_recall: 0.9591 - val_accuracy: 0.9727
# Epoch 48/50
# 2033/2033 [==============================] - 220s 108ms/step - loss: 1.2415e-04 - iou: 1.0000 - dice_coef: 0.9999 - precision: 1.0000 - recall: 1.0000 - accuracy: 1.0000 - val_loss: 0.1499 - val_iou: 0.9993 - val_dice_coef: 0.9577 - val_precision: 0.9591 - val_recall: 0.9568 - val_accuracy: 0.9720
# Epoch 49/50
# 2033/2033 [==============================] - 225s 111ms/step - loss: 7.0219e-05 - iou: 1.0000 - dice_coef: 0.9999 - precision: 1.0000 - recall: 1.0000 - accuracy: 1.0000 - val_loss: 0.1536 - val_iou: 0.9993 - val_dice_coef: 0.9594 - val_precision: 0.9659 - val_recall: 0.9636 - val_accuracy: 0.9765
# Epoch 50/50
# 2033/2033 [==============================] - 222s 109ms/step - loss: 4.8891e-05 - iou: 1.0000 - dice_coef: 1.0000 - precision: 1.0000 - recall: 1.0000 - accuracy: 1.0000 - val_loss: 0.1545 - val_iou: 0.9994 - val_dice_coef: 0.9601 - val_precision: 0.9636 - val_recall: 0.9636 - val_accuracy: 0.9758

# %%
model_1 = Model(inputs=img_input, outputs=pred)
model_1.compile(optimizer= Adam(lr=0.0001, beta_1=0.9, beta_2=0.999, amsgrad=False, decay=0.0005), loss= ['categorical_crossentropy'], metrics=[iou, dice_coef,precision, recall,accuracy])

# %%
model_1.load_weights('My_Mod150.h5')

# %%
print('\n~~~~~~~~~~~~~~~Stats after 150 epoch~~~~~~~~~~~~~~~~~~~')
print('\n-------------On Train Set--------------------------\n')
res = model_1.evaluate(X_t,Y_t, batch_size= 10)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')
print('\n-------------On Test  Set--------------------------\n')
res = model_1.evaluate(X_test, Y_test, batch_size= 10)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')
print('\n-------------On validation Set---------------------\n')
res = model_1.evaluate(X_valid, Y_valid, batch_size= 10)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')
# Out:
# ~~~~~~~~~~~~~~~Stats after 150 epoch~~~~~~~~~~~~~~~~~~~
#
# -------------On Train Set--------------------------
#
# 2033/2033 [==============================] - 67s 33ms/step
# ________________________
# IOU:       |   100.00  |
# Dice Coef: |   100.00  |
# Precision: |   100.00  |
# Recall:    |   100.00  |
# Accuracy:  |   100.00  |
# Loss:      |   0.00  |
# ________________________
#
# -------------On Test  Set--------------------------
#
# 436/436 [==============================] - 14s 32ms/step
# ________________________
# IOU:       |   99.95  |
# Dice Coef: |   96.48  |
# Precision: |   96.77  |
# Recall:    |   96.36  |
# Accuracy:  |   97.73  |
# Loss:      |   13.99  |
# ________________________
#
# -------------On validation Set---------------------
#
# 436/436 [==============================] - 14s 33ms/step
# ________________________
# IOU:       |   99.94  |
# Dice Coef: |   96.01  |
# Precision: |   96.36  |
# Recall:    |   96.36  |
# Accuracy:  |   97.58  |
# Loss:      |   15.45  |
# ________________________

# %%
plt.figure(figsize=(20, 14))
plt.suptitle('Training Statistics on Train Set')
plt.subplot(2,2,1)
plt.plot(history.history['loss'], 'red')
plt.title('Loss')
plt.subplot(2,2,2)
plt.plot(history.history['accuracy'], 'green')
plt.title('Accuracy')
plt.subplot(2,2,3)
plt.plot(history.history['val_loss'], 'red')
plt.yticks(list(np.arange(0.0, 1.0, 0.10)))
plt.title('Valdiation Loss')
plt.subplot(2,2,4)
plt.plot(history.history['val_accuracy'], 'green')
plt.yticks(list(np.arange(0.0, 1.0, 0.10)))
plt.title('Validation Accuracy')
plt.show()

# %%
img_num = 49
img_pred = model_1.predict(X_test[img_num].reshape(-1,256,256,1))
plt.imshow(X_test[img_num].reshape(256,256), plt.cm.binary_r)
print(Y_test[img_num])
print(img_pred)
# Out:
# [1 0 0]
# [[9.9909317e-01 7.4018885e-06 8.9944154e-04]]

# %%
end_labels = ["NORMAL","COVID-19","Viral Pneumonia"]
def getEngLabels(pred):
  if len(pred.shape)==1:
    pred = list(pred)
    return end_labels[pred.index(max(pred))]
  result=[]
  for i in range(0,len(pred)):
    currPred= list(pred[i])
    result.append(end_labels[currPred.index(max(currPred))])
  return result


img_num = 255
img_pred = model_1.predict(X_test[img_num].reshape(-1,256,256,1))
img_pred.reshape(-1,3)
plt.imshow(X_test[img_num].reshape(256,256), plt.cm.binary_r)
j=(Y_test[img_num])
j1=getEngLabels(j)
print(j1)
x=getEngLabels(img_pred)
print(x)
# Out:
# COVID-19
# ['COVID-19']

# %%
confusion_matrix(j1, x)
# Out:
# array([[ 26,   2,   0],
#        [  0, 201,   6],
#        [  0,   7, 194]])

# %%
import seaborn as sns

# %%
cm=confusion_matrix(j1, x)
plt.figure(figsize=(6, 6))
ax = sns.heatmap(cm, cmap="rocket_r", fmt=".01f",annot_kws={'size':16}, annot=True, square=True, xticklabels=label, yticklabels=label)
ax.set_ylabel('Actual', fontsize=20)
ax.set_xlabel('Predicted', fontsize=20)
# Out:
# Text(0.5, 62.15999999999998, 'Predicted')
